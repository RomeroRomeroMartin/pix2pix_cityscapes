# %%
import glob
import torch
from PIL import Image
from torch.utils.data import Dataset
from torch.utils.data import random_split, DataLoader
from dataset.cityscapes import *
from dataset.transforms import * 
from dataset.utils import *
import torch
from torch import nn
from torch.utils.data import DataLoader
import time
import argparse
from progress.bar import IncrementalBar
from dataset import Cityscapes
from dataset import transforms as T
from gan.generator3 import Generator
from gan.discriminator3 import Discriminator
from gan.criterion import GeneratorLoss, DiscriminatorLoss
from gan.utils import *
from torchmetrics.image import StructuralSimilarityIndexMeasure as SSIM

# %%
device = ('cuda:0' if torch.cuda.is_available() else 'cpu')
print(f"Code runs in {device}")
# Out:
# Code runs in cuda:0

# %%
# Hyperparameters
epochs = 200
batch_size = 1
lr = 0.0002
save_image_interval = 2

# %%
#transforms = T.Compose([T.ToTensor()])


transforms = T.Compose([#T.HorizontalFlip(),
                        #T.CustomColorJitter(),
                        T.ToTensor(),
                        #T.Normalize(mean=[0.5, 0.5, 0.5], std=[0.5, 0.5, 0.5])
                        ])      

cityscapes = Cityscapes(transform=transforms)
train_set, val_set, test_set = cityscapes.divide_into_sets()

# %%
# Assuming 'train_set' is already defined and loaded
visualize_samples(train_set, num_samples=2)

# %%
train_loader = DataLoader(train_set, batch_size=batch_size, shuffle=True)
val_loader = DataLoader(val_set, batch_size=batch_size, shuffle=False)
test_loader = DataLoader(test_set, batch_size=batch_size, shuffle=False)

# %%
# models
print('Defining models!')
generator = Generator().to(device)
discriminator = Discriminator().to(device)
# optimizers
g_optimizer = torch.optim.Adam(generator.parameters(), lr=lr, betas=(0.5, 0.999))
d_optimizer = torch.optim.Adam(discriminator.parameters(), lr=lr, betas=(0.5, 0.999))
# loss functions
g_criterion = GeneratorLoss(alpha=100)
d_criterion = DiscriminatorLoss()
# Out:
# Defining models!
# /home/martin/miniconda3/envs/cv2/lib/python3.12/site-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /home/martin/miniconda3/envs/cv2/lib/python3.12/site-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=DeepLabV3_ResNet50_Weights.COCO_WITH_VOC_LABELS_V1`. You can also use `weights=DeepLabV3_ResNet50_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# /home/martin/miniconda3/envs/cv2/lib/python3.12/site-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=ResNet18_Weights.IMAGENET1K_V1`. You can also use `weights=ResNet18_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)

# %%
ssim_metric = SSIM(data_range=1.0).to(device)

# %%
print('Start of training process!')
logger = Logger(filename='cityscapes_dataset')

# Training Loop
for epoch in range(epochs):
    generator.train()
    discriminator.train()
    train_g_loss = 0.0
    train_d_loss = 0.0
    start = time.time()
    bar = IncrementalBar(f'[Epoch {epoch+1}/{epochs}]', max=len(train_loader))
    train_ssim_values = []

    for i, (x, real) in enumerate(train_loader):
        x = x.to(device)
        real = real.to(device)

        # Train Discriminator
        fake = generator(x)
        d_real_pred = discriminator(real, x)
        d_fake_pred = discriminator(fake.detach(), x)
        d_loss = d_criterion(d_real_pred, d_fake_pred)

        d_optimizer.zero_grad()
        d_loss.backward()
        d_optimizer.step()

        # Train Generator
        g_fake_pred = discriminator(fake, x)
        g_loss = g_criterion(fake, real, g_fake_pred)

        g_optimizer.zero_grad()
        g_loss.backward()
        g_optimizer.step()

        train_g_loss += g_loss.item()
        train_d_loss += d_loss.item()
        bar.next()

        ssim = ssim_metric(fake, real)
        train_ssim_values.append(ssim.item())
        # Save generated images periodically
        if (epoch % save_image_interval == 0):  # Adjust as necessary
            save_sample(logger,convert2_0_1(real), convert2_0_1(fake), epoch, i)
    
    train_avg_ssim = sum(train_ssim_values) / len(train_ssim_values)

    bar.finish()
    train_g_loss /= len(train_loader)
    train_d_loss /= len(train_loader)

    # Validation Loop
    generator.eval()
    discriminator.eval()
    val_g_loss = 0.0
    val_d_loss = 0.0
    val_ssim_values = []
    with torch.no_grad():
        for x, real in val_loader:
            x = x.to(device)
            real = real.to(device)
            fake = generator(x)
            d_real_pred = discriminator(real, x)
            d_fake_pred = discriminator(fake, x)
            val_d_loss += d_criterion(d_real_pred, d_fake_pred).item()
            g_fake_pred = discriminator(fake, x)
            val_g_loss += g_criterion(fake, real, g_fake_pred).item()
            ssim = ssim_metric(fake, real)
            val_ssim_values.append(ssim.item())

    val_avg_ssim = sum(val_ssim_values) / len(val_ssim_values)
    val_g_loss /= len(val_loader)
    val_d_loss /= len(val_loader)

    # Logging
    logger.add_scalar('train_generator_loss', train_g_loss, epoch+1)
    logger.add_scalar('train_discriminator_loss', train_d_loss, epoch+1)
    logger.add_scalar('val_generator_loss', val_g_loss, epoch+1)
    logger.add_scalar('val_discriminator_loss', val_d_loss, epoch+1)
    logger.update()

    print(f"[Epoch {epoch+1}/{epochs}] Train G loss: {train_g_loss:.3f} Train D loss: {train_d_loss:.3f} Train SSIM: {train_avg_ssim:.3f} Val G loss: {val_g_loss:.3f} Val D loss: {val_d_loss:.3f} Val SSIM: {val_avg_ssim:.3f}")

    # Save model weights
    if (epoch + 1) % 10 == 0:
        logger.save_weights(generator.state_dict(), f'generator_epoch_{epoch+1}')
        logger.save_weights(discriminator.state_dict(), f'discriminator_epoch_{epoch+1}')



logger.close()
print('End of training process!')
# Out:
# Start of training process!
# [Epoch 1/200] Train G loss: 11.715 Train D loss: 0.645 Train SSIM: 0.507 Val G loss: 11.361 Val D loss: 0.693 Val SSIM: 0.524
# [Epoch 2/200] Train G loss: 10.693 Train D loss: 0.693 Train SSIM: 0.532 Val G loss: 11.222 Val D loss: 0.693 Val SSIM: 0.522
# [Epoch 3/200] Train G loss: 10.211 Train D loss: 0.693 Train SSIM: 0.539 Val G loss: 10.897 Val D loss: 0.693 Val SSIM: 0.525
# [Epoch 4/200] Train G loss: 9.862 Train D loss: 0.693 Train SSIM: 0.543 Val G loss: 11.800 Val D loss: 0.693 Val SSIM: 0.512
# [Epoch 5/200] Train G loss: 9.653 Train D loss: 0.693 Train SSIM: 0.545 Val G loss: 11.470 Val D loss: 0.693 Val SSIM: 0.525
# [Epoch 6/200] Train G loss: 9.228 Train D loss: 0.693 Train SSIM: 0.550 Val G loss: 10.713 Val D loss: 0.693 Val SSIM: 0.532
# [Epoch 7/200] Train G loss: 8.917 Train D loss: 0.693 Train SSIM: 0.553 Val G loss: 11.047 Val D loss: 0.693 Val SSIM: 0.526
# [Epoch 8/200] Train G loss: 8.627 Train D loss: 0.693 Train SSIM: 0.555 Val G loss: 10.856 Val D loss: 0.693 Val SSIM: 0.530
# [Epoch 9/200] Train G loss: 8.031 Train D loss: 0.775 Train SSIM: 0.559 Val G loss: 10.875 Val D loss: 0.813 Val SSIM: 0.525
# [Epoch 10/200] Train G loss: 7.673 Train D loss: 0.813 Train SSIM: 0.562 Val G loss: 10.389 Val D loss: 0.813 Val SSIM: 0.527
# [Epoch 11/200] Train G loss: 7.393 Train D loss: 0.813 Train SSIM: 0.565 Val G loss: 10.869 Val D loss: 0.813 Val SSIM: 0.525
# [Epoch 12/200] Train G loss: 7.126 Train D loss: 0.813 Train SSIM: 0.569 Val G loss: 10.807 Val D loss: 0.813 Val SSIM: 0.525
# [Epoch 13/200] Train G loss: 6.906 Train D loss: 0.813 Train SSIM: 0.572 Val G loss: 10.796 Val D loss: 0.813 Val SSIM: 0.526
# [Epoch 14/200] Train G loss: 6.738 Train D loss: 0.813 Train SSIM: 0.575 Val G loss: 10.286 Val D loss: 0.813 Val SSIM: 0.531
# [Epoch
Train D loss: 0.813 Train SSIM: 0.640 Val G loss: 10.540 Val D loss: 0.813 Val SSIM: 0.530
# [Epoch 178/200] Train G loss: 4.209 Train D loss: 0.813 Train SSIM: 0.640 Val G loss: 10.385 Val D loss: 0.813 Val SSIM: 0.532
# [Epoch 179/200] Train G loss: 4.207 Train D loss: 0.813 Train SSIM: 0.640 Val G loss: 10.265 Val D loss: 0.813 Val SSIM: 0.534
# [Epoch 180/200] Train G loss: 4.200 Train D loss: 0.813 Train SSIM: 0.640 Val G loss: 10.232 Val D loss: 0.813 Val SSIM: 0.533
# [Epoch 181/200] Train G loss: 4.202 Train D loss: 0.813 Train SSIM: 0.640 Val G loss: 10.119 Val D loss: 0.813 Val SSIM: 0.535
# [Epoch 182/200] Train G loss: 4.210 Train D loss: 0.813 Train SSIM: 0.640 Val G loss: 10.224 Val D loss: 0.813 Val SSIM: 0.535
# [Epoch 183/200] Train G loss: 4.203 Train D loss: 0.813 Train SSIM: 0.640 Val G loss: 10.326 Val D loss: 0.813 Val SSIM: 0.532
# [Epoch 184/200] Train G loss: 4.199 Train D loss: 0.813 Train SSIM: 0.641 Val G loss: 10.185 Val D loss: 0.813 Val SSIM: 0.534
# [Epoch 185/200] Train G loss: 4.195 Train D loss: 0.813 Train SSIM: 0.641 Val G loss: 10.160 Val D loss: 0.813 Val SSIM: 0.535
# [Epoch 186/200] Train G loss: 4.208 Train D loss: 0.813 Train SSIM: 0.640 Val G loss: 10.486 Val D loss: 0.813 Val SSIM: 0.532
# [Epoch 187/200] Train G loss: 4.200 Train D loss: 0.813 Train SSIM: 0.641 Val G loss: 10.333 Val D loss: 0.813 Val SSIM: 0.533
# [Epoch 188/200] Train G loss: 4.195 Train D loss: 0.813 Train SSIM: 0.641 Val G loss: 10.472 Val D loss: 0.813 Val SSIM: 0.530
# [Epoch 189/200] Train G loss: 4.196 Train D loss: 0.813 Train SSIM: 0.641 Val G loss: 10.317 Val D loss: 0.813 Val SSIM: 0.533
# [Epoch 190/200] Train G loss: 4.192 Train D loss: 0.813 Train SSIM: 0.641 Val G loss: 10.310 Val D loss: 0.813 Val SSIM: 0.533
# [Epoch 191/200] Train G loss: 4.189 Train D loss: 0.813 Train SSIM: 0.641 Val G loss: 10.215 Val D loss: 0.813 Val SSIM: 0.534
# [Epoch 192/200] Train G loss: 4.190 Train D loss: 0.813 Train SSIM: 0.641 Val G loss: 10.226 Val D loss: 0.813 Val SSIM: 0.534
# [Epoch 193/200] Train G loss: 4.188 Train D loss: 0.813 Train SSIM: 0.641 Val G loss: 10.188 Val D loss: 0.813 Val SSIM: 0.535
# [Epoch 194/200] Train G loss: 4.188 Train D loss: 0.813 Train SSIM: 0.641 Val G loss: 10.280 Val D loss: 0.813 Val SSIM: 0.533
# [Epoch 195/200] Train G loss: 4.188 Train D loss: 0.813 Train SSIM: 0.641 Val G loss: 10.189 Val D loss: 0.813 Val SSIM: 0.536
# [Epoch 196/200] Train G loss: 4.186 Train D loss: 0.813 Train SSIM: 0.641 Val G loss: 10.245 Val D loss: 0.813 Val SSIM: 0.534
# [Epoch 197/200] Train G loss: 4.185 Train D loss: 0.813 Train SSIM: 0.641 Val G loss: 10.373 Val D loss: 0.813 Val SSIM: 0.534
# [Epoch 198/200] Train G loss: 4.184 Train D loss: 0.813 Train SSIM: 0.641 Val G loss: 10.300 Val D loss: 0.813 Val SSIM: 0.534
# [Epoch 199/200] Train G loss: 4.190 Train D loss: 0.813 Train SSIM: 0.641 Val G loss: 10.453 Val D loss: 0.813 Val SSIM: 0.532
# [Epoch 200/200] Train G loss: 4.187 Train D loss: 0.813 Train SSIM: 0.641 Val G loss: 10.247 Val D loss: 0.813 Val SSIM: 0.535
# End of training process!

# %%
# Evaluate the model in test set
generator.eval()  # Set the generator in validation mode
discriminator.eval()  # set the discriminator in validation mode (if needed)
test_g_loss = 0.0
test_d_loss = 0.0
test_ssim_values = []
i=0
# Initialize the calculation of the metrics with torch.no_grad() to avoid calculating gradients
with torch.no_grad():
    for x, real in test_loader:
        x = x.to(device)
        real = real.to(device)
        
        # Generate images with the generator
        fake = generator(x)
        
        # Calculate the predictions of the discriminator
        d_real_pred = discriminator(real, x)
        d_fake_pred = discriminator(fake, x)
        
        # Calculate the loss of the discriminator
        test_d_loss += d_criterion(d_real_pred, d_fake_pred).item()
        
        # Calculate the loss of the generator
        g_fake_pred = discriminator(fake, x)
        test_g_loss += g_criterion(fake, real, g_fake_pred).item()
        
        # Calculate SSIM
        ssim = ssim_metric(fake, real)
        test_ssim_values.append(ssim.item())

        save_sample(logger,convert2_0_1(real), convert2_0_1(fake), 1, i, prefix='test')
        i+=1

# Calculate the averages of the metrics
test_g_loss /= len(test_loader)
test_d_loss /= len(test_loader)
test_avg_ssim = sum(test_ssim_values) / len(test_ssim_values)

# Show the results of the evaluation on the test set
print(f"Test Results: Test G loss: {test_g_loss:.3f}, Test D loss: {test_d_loss:.3f}, Test SSIM: {test_avg_ssim:.3f}")

# If you have a logger, you can also log the results of the test set evaluation
logger.add_scalar('test_generator_loss', test_g_loss, epoch+1)
logger.add_scalar('test_discriminator_loss', test_d_loss, epoch+1)
logger.add_scalar('test_ssim', test_avg_ssim, epoch+1)
# Out:
# Test Results: Test G loss: 11.553, Test D loss: 0.813, Test SSIM: 0.505
