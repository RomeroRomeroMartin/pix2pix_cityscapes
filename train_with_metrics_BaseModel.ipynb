# %%
import glob
import torch
from PIL import Image
from torch.utils.data import Dataset
from torch.utils.data import random_split, DataLoader
from dataset.cityscapes import *
from dataset.transforms import * 
from dataset.utils import *
import torch
from torch import nn
from torch.utils.data import DataLoader
import time
import argparse
from progress.bar import IncrementalBar
from dataset import Cityscapes
from dataset import transforms as T
from gan.generator2 import Generator
from gan.discriminator2 import Discriminator
from gan.criterion import GeneratorLoss, DiscriminatorLoss
from gan.utils import *
from torchmetrics.image import StructuralSimilarityIndexMeasure as SSIM
import torchvision.transforms as transf

# %%
device = ('cuda:0' if torch.cuda.is_available() else 'cpu')
print(f"Code runs in {device}")
# Out:
# Code runs in cpu
# /home/martin/miniconda3/envs/cv2/lib/python3.12/site-packages/torch/cuda/__init__.py:141: UserWarning: CUDA initialization: CUDA unknown error - this may be due to an incorrectly set up environment, e.g. changing env variable CUDA_VISIBLE_DEVICES after program start. Setting the available devices to be zero. (Triggered internally at ../c10/cuda/CUDAFunctions.cpp:108.)
#   return torch._C._cuda_getDeviceCount() > 0

# %%
# Hyperparameters
epochs = 200
batch_size = 1
lr = 0.0002
save_image_interval = 2

# %%
#transforms = T.Compose([T.ToTensor()])


transforms = T.Compose([#T.HorizontalFlip(),
                        #T.CustomColorJitter(),
                        T.ToTensor(),
                        #T.Normalize(mean=[0.5, 0.5, 0.5], std=[0.5, 0.5, 0.5])
                        ])            
                       


cityscapes = Cityscapes(transform=transforms)
train_set, val_set, test_set = cityscapes.divide_into_sets()

# %%
# Assuming 'train_set' is already defined and lo
visualize_samples(train_set, num_samples=2)
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
train_loader = DataLoader(train_set, batch_size=batch_size, shuffle=True)
val_loader = DataLoader(val_set, batch_size=batch_size, shuffle=False)
test_loader = DataLoader(test_set, batch_size=batch_size, shuffle=False)

# %%
# models
print('Defining models!')
generator = Generator().to(device)
discriminator = Discriminator().to(device)
# optimizers
g_optimizer = torch.optim.Adam(generator.parameters(), lr=lr, betas=(0.5, 0.999))
d_optimizer = torch.optim.Adam(discriminator.parameters(), lr=lr, betas=(0.5, 0.999))
# loss functions
g_criterion = GeneratorLoss(alpha=100)
d_criterion = DiscriminatorLoss()
# Out:
# Defining models!

# %%
ssim_metric = SSIM(data_range=1.0).to(device)

# %%
print('Start of training process!')
logger = Logger(filename='cityscapes_dataset')

# Training Loop
for epoch in range(epochs):
    generator.train()
    discriminator.train()
    train_g_loss = 0.0
    train_d_loss = 0.0
    start = time.time()
    bar = IncrementalBar(f'[Epoch {epoch+1}/{epochs}]', max=len(train_loader))
    train_ssim_values = []

    for i, (x, real) in enumerate(train_loader):
        x = x.to(device)
        real = real.to(device)

        # Train Discriminator
        fake = generator(x)
        d_real_pred = discriminator(real, x)
        d_fake_pred = discriminator(fake.detach(), x)
        d_loss = d_criterion(d_real_pred, d_fake_pred)

        d_optimizer.zero_grad()
        d_loss.backward()
        d_optimizer.step()

        # Train Generator
        g_fake_pred = discriminator(fake, x)
        g_loss = g_criterion(fake, real, g_fake_pred)

        g_optimizer.zero_grad()
        g_loss.backward()
        g_optimizer.step()

        train_g_loss += g_loss.item()
        train_d_loss += d_loss.item()
        bar.next()

        ssim = ssim_metric(fake, real)
        train_ssim_values.append(ssim.item())
        # Save generated images periodically
        if (epoch % save_image_interval == 0):  # Adjust as necessary
            save_sample(logger,convert2_0_1(real), convert2_0_1(fake), epoch, i)
    
    train_avg_ssim = sum(train_ssim_values) / len(train_ssim_values)

    bar.finish()
    train_g_loss /= len(train_loader)
    train_d_loss /= len(train_loader)

    # Validation Loop
    generator.eval()
    discriminator.eval()
    val_g_loss = 0.0
    val_d_loss = 0.0
    val_ssim_values = []
    with torch.no_grad():
        for x, real in val_loader:
            x = x.to(device)
            real = real.to(device)
            fake = generator(x)
            d_real_pred = discriminator(real, x)
            d_fake_pred = discriminator(fake, x)
            val_d_loss += d_criterion(d_real_pred, d_fake_pred).item()
            g_fake_pred = discriminator(fake, x)
            val_g_loss += g_criterion(fake, real, g_fake_pred).item()
            ssim = ssim_metric(fake, real)
            val_ssim_values.append(ssim.item())

    val_avg_ssim = sum(val_ssim_values) / len(val_ssim_values)
    val_g_loss /= len(val_loader)
    val_d_loss /= len(val_loader)

    # Logging
    logger.add_scalar('train_generator_loss', train_g_loss, epoch+1)
    logger.add_scalar('train_discriminator_loss', train_d_loss, epoch+1)
    logger.add_scalar('val_generator_loss', val_g_loss, epoch+1)
    logger.add_scalar('val_discriminator_loss', val_d_loss, epoch+1)
    logger.update()

    print(f"[Epoch {epoch+1}/{epochs}] Train G loss: {train_g_loss:.3f} Train D loss: {train_d_loss:.3f} Train SSIM: {train_avg_ssim:.3f} Val G loss: {val_g_loss:.3f} Val D loss: {val_d_loss:.3f} Val SSIM: {val_avg_ssim:.3f}")

    # Save model weights
    if (epoch + 1) % 10 == 0:
        logger.save_weights(generator.state_dict(), f'generator_epoch_{epoch+1}')
        logger.save_weights(discriminator.state_dict(), f'discriminator_epoch_{epoch+1}')



logger.close()
print('End of training process!')
# Out:
# Start of training process!
# [Epoch 1/200] Train G loss: 27.605 Train D loss: 0.547 Train SSIM: 0.123 Val G loss: 23.719 Val D loss: 0.821 Val SSIM: 0.221
# [Epoch 2/200] Train G loss: 23.613 Train D loss: 0.545 Train SSIM: 0.186 Val G loss: 23.741 Val D loss: 0.818 Val SSIM: 0.212
# [Epoch 3/200] Train G loss: 22.484 Train D loss: 0.523 Train SSIM: 0.201 Val G loss: 23.482 Val D loss: 0.795 Val SSIM: 0.219
# [Epoch 4/200] Train G loss: 22.068 Train D loss: 0.518 Train SSIM: 0.221 Val G loss: 22.624 Val D loss: 0.824 Val SSIM: 0.252
# [Epoch 5/200] Train G loss: 21.803 Train D loss: 0.516 Train SSIM: 0.237 Val G loss: 23.999 Val D loss: 0.826 Val SSIM: 0.232
# [Epoch 6/200] Train G loss: 21.681 Train D loss: 0.514 Train SSIM: 0.247 Val G loss: 22.630 Val D loss: 0.816 Val SSIM: 0.266
# [Epoch 7/200] Train G loss: 21.695 Train D loss: 0.515 Train SSIM: 0.254 Val G loss: 22.262 Val D loss: 0.817 Val SSIM: 0.268
# [Epoch 8/200] Train G loss: 21.691 Train D loss: 0.512 Train SSIM: 0.257 Val G loss: 23.077 Val D loss: 0.813 Val SSIM: 0.261
# [Epoch 9/200] Train G loss: 21.498 Train D loss: 0.508 Train SSIM: 0.260 Val G loss: 22.710 Val D loss: 0.812 Val SSIM: 0.274
# [Epoch 10/200] Train G loss: 21.262 Train D loss: 0.505 Train SSIM: 0.268 Val G loss: 23.368 Val D loss: 0.811 Val SSIM: 0.267
# [Epoch 11/200] Train G loss: 20.995 Train D loss: 0.505 Train SSIM: 0.273 Val G loss: 22.861 Val D loss: 0.813 Val SSIM: 0.272
# [Epoch 12/200] Train G loss: 21.203 Train D loss: 0.505 Train SSIM: 0.273 Val G loss: 23.212 Val D loss: 0.810 Val SSIM: 0.280
# [Epoch 13/200] Train G loss: 21.088 Train D loss: 0.504 Train SSIM: 0.277 Val G loss: 23.149 Val D loss: 0.813 Val SSIM: 0.276
# [Epoch 14/200] Train G loss: 20.705 Train D loss: 0.504 Train SSIM: 0.282 Val G loss: 22.714 Val D loss: 0.804 Val SSIM: 0.284
# [Epoch 15/200] Train G loss: 20.518 Train D loss: 0.503 Train SSIM: 0.286 Val G loss: 23.086 Val D loss: 0.810 Val SSIM: 0.287
Train D loss: 0.503 Train SSIM: 0.370 Val G loss: 23.371 Val D loss: 0.805 Val SSIM: 0.323
# [Epoch 192/200] Train G loss: 15.856 Train D loss: 0.503 Train SSIM: 0.373 Val G loss: 23.120 Val D loss: 0.806 Val SSIM: 0.320
# [Epoch 193/200] Train G loss: 15.972 Train D loss: 0.503 Train SSIM: 0.371 Val G loss: 23.074 Val D loss: 0.806 Val SSIM: 0.324
# [Epoch 194/200] Train G loss: 15.964 Train D loss: 0.503 Train SSIM: 0.371 Val G loss: 23.452 Val D loss: 0.805 Val SSIM: 0.319
# [Epoch 195/200] Train G loss: 15.972 Train D loss: 0.503 Train SSIM: 0.371 Val G loss: 22.875 Val D loss: 0.805 Val SSIM: 0.326
# [Epoch 196/200] Train G loss: 15.921 Train D loss: 0.503 Train SSIM: 0.371 Val G loss: 22.988 Val D loss: 0.806 Val SSIM: 0.325
# [Epoch 197/200] Train G loss: 15.899 Train D loss: 0.503 Train SSIM: 0.370 Val G loss: 23.414 Val D loss: 0.806 Val SSIM: 0.321
# [Epoch 198/200] Train G loss: 15.845 Train D loss: 0.503 Train SSIM: 0.373 Val G loss: 23.035 Val D loss: 0.807 Val SSIM: 0.324
# [Epoch 199/200] Train G loss: 16.063 Train D loss: 0.503 Train SSIM: 0.370 Val G loss: 23.523 Val D loss: 0.807 Val SSIM: 0.319
# [Epoch 200/200] Train G loss: 16.055 Train D loss: 0.503 Train SSIM: 0.369 Val G loss: 23.339 Val D loss: 0.807 Val SSIM: 0.324
# End of training process!

# %%
# Evaluate the model on the test set
generator.eval()   # Change the generator to evaluation mode
discriminator.eval()  # Change the discriminator to evaluation mode (if necessary)
test_g_loss = 0.0
test_d_loss = 0.0
test_ssim_values = []
i=0
# Initialize the calculation of the metrics with torch.no_grad() to avoid calculating gradients
with torch.no_grad():
    for x, real in test_loader:
        x = x.to(device)
        real = real.to(device)
        
        # Generate images with the generator
        fake = generator(x)
        
        # Calculate the predictions of the discriminator
        d_real_pred = discriminator(real, x)
        d_fake_pred = discriminator(fake, x)
        
        # Calculate the loss of the discriminator
        test_d_loss += d_criterion(d_real_pred, d_fake_pred).item()
        
        # Calculate the loss of the generator
        g_fake_pred = discriminator(fake, x)
        test_g_loss += g_criterion(fake, real, g_fake_pred).item()
        
        # Calculate SSIM
        ssim = ssim_metric(fake, real)
        test_ssim_values.append(ssim.item())

        save_sample(logger,convert2_0_1(real), convert2_0_1(fake), 1, i, prefix='test')
        i+=1

# Calculate the averages of the metrics
test_g_loss /= len(test_loader)
test_d_loss /= len(test_loader)
test_avg_ssim = sum(test_ssim_values) / len(test_ssim_values)

# Show the results of the evaluation on the test set
print(f"Test Results: Test G loss: {test_g_loss:.3f}, Test D loss: {test_d_loss:.3f}, Test SSIM: {test_avg_ssim:.3f}")

# If you have a logger, you can also log the results of the test set evaluation
logger.add_scalar('test_generator_loss', test_g_loss, epoch+1)
logger.add_scalar('test_discriminator_loss', test_d_loss, epoch+1)
logger.add_scalar('test_ssim', test_avg_ssim, epoch+1)
# Out:
# Test Results: Test G loss: 24.193, Test D loss: 0.808, Test SSIM: 0.301
